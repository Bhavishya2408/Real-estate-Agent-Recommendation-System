# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("past sales.csv")

# %%
df
# Out:
#              Id  loc_id                      Property_Details_address    Side  \
# 0             1       1        103 Singingwood Dr, Holbrook, NY 11741  Seller
# 1             2       1        226 Fairfield Dr E, Holbrook, NY 11741  Seller
# 2             3       1      631 Greenbelt Pkwy W, Holbrook, NY 11741  Seller
# 3             4       1               115 Dari Dr, Holbrook, NY 11741  Seller
# 4             5       1             1 Saggese Ln, Nesconset, NY 11767   Buyer
# ...         ...     ...                                           ...     ...
# 999995  1000852  787086  6101 Township Road 175, Cardington, OH 43315   Buyer
# 999996  1000853  255202            2312 Webster Ave, Joliet, IL 60436  Seller
# 999997  1000854  563205          1310 Forest Ave, Cambridge, OH 43725  Seller
# 999998  1000855  549605                  1000 Elm St, Piqua, OH 45356   Buyer
# 999999  1000856  885212               5546 Malta St, Denver, CO 80249   Buyer
#
#            Price   Sold_Date
# 0       $343,000  03/30/2020
# 1       $535,000  03/30/2020
# 2       $390,000  03/26/2020
# 3       $353,000  03/12/2020
# 4       $425,000  02/14/2020
# ...          ...         ...
# 999995  $114,900  12/18/2014
# 999996  $133,000  01/16/2018
# 999997  $130,000  02/06/2019
# 999998   $91,500  06/06/2018
# 999999  $174,000  08/10/2012
#
# [1000000 rows x 6 columns]

# %%
print("Missing values before cleaning:\n", df.isnull().sum())
# Out:
# Missing values before cleaning:
#  Id                              0
# loc_id                          0
# Property_Details_address    25167
# Side                            0
# Price                           0
# Sold_Date                       0
# dtype: int64

# %%
### Converting Sold_Date to datetime
df['Sold_Date'] = pd.to_datetime(df['Sold_Date'])

# %%
### Adding Month and Year columns for analysis
df['Month'] = df['Sold_Date'].dt.month
df['Year'] = df['Sold_Date'].dt.year

# %%
print("Unique Price values before cleaning:", df['Price'].unique())
# Out:
# Unique Price values before cleaning: ['$343,000' '$535,000' '$390,000' ... '$49,873' '$555,505' '$351,111']

# %%
### Cleaning the Price column
df['Price'] = df['Price'].replace('[\$,]', '', regex=True) 
df['Price'] = df['Price'].replace('--', None)           
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\jayan\AppData\Local\Temp\ipykernel_29600\3213641818.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df['Price'] = df['Price'].replace('[\$,]', '', regex=True)

# %%
### Fill missing values if necessary
if df['Price'].isnull().any():
    print("Missing values detected. Filling with the mean price.")
    df['Price'] = df['Price'].fillna(df['Price'].mean())
# Out:
# Missing values detected. Filling with the mean price.

# %%
### Adding a feature for Price per loc_id average
df['Avg_Price_loc_id'] = df.groupby('loc_id')['Price'].transform('mean')

# %%
### Adding a feature for whether the property was sold above or below loc_id average
df['Above_Avg'] = df['Price'] > df['Avg_Price_loc_id']

# %%
df['Total_Sales_per_Loc'] = df.groupby('loc_id')['Id'].transform('count')

# %%
df
# Out:
#              Id  loc_id                      Property_Details_address    Side  \
# 0             1       1        103 Singingwood Dr, Holbrook, NY 11741  Seller
# 1             2       1        226 Fairfield Dr E, Holbrook, NY 11741  Seller
# 2             3       1      631 Greenbelt Pkwy W, Holbrook, NY 11741  Seller
# 3             4       1               115 Dari Dr, Holbrook, NY 11741  Seller
# 4             5       1             1 Saggese Ln, Nesconset, NY 11767   Buyer
# ...         ...     ...                                           ...     ...
# 999995  1000852  787086  6101 Township Road 175, Cardington, OH 43315   Buyer
# 999996  1000853  255202            2312 Webster Ave, Joliet, IL 60436  Seller
# 999997  1000854  563205          1310 Forest Ave, Cambridge, OH 43725  Seller
# 999998  1000855  549605                  1000 Elm St, Piqua, OH 45356   Buyer
# 999999  1000856  885212               5546 Malta St, Denver, CO 80249   Buyer
#
#            Price  Sold_Date  Month  Year  Avg_Price_loc_id  Above_Avg  \
# 0       343000.0 2020-03-30      3  2020          409200.0      False
# 1       535000.0 2020-03-30      3  2020          409200.0       True
# 2       390000.0 2020-03-26      3  2020          409200.0      False
# 3       353000.0 2020-03-12      3  2020          409200.0      False
# 4       425000.0 2020-02-14      2  2020          409200.0       True
# ...          ...        ...    ...   ...               ...        ...
# 999995  114900.0 2014-12-18     12  2014           87700.0       True
# 999996  133000.0 2018-01-16      1  2018          182174.6      False
# 999997  130000.0 2019-02-06      2  2019           78500.0       True
# 999998   91500.0 2018-06-06      6  2018           97875.0      False
# 999999  174000.0 2012-08-10      8  2012          282000.0      False
#
#         Total_Sales_per_Loc
# 0                         5
# 1                         5
# 2                         5
# 3                         5
# 4                         5
# ...                     ...
# 999995                    2
# 999996                    5
# 999997                    4
# 999998                    4
# 999999                    4
#
# [1000000 rows x 11 columns]

# %%
### Price Distribution by Side
plt.figure(figsize=(8, 5))
for side, group in df.groupby('Side'):
    group['Price'].plot(kind='hist', alpha=0.6, label=side, bins=10)

plt.title('Price Distribution by Side')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.legend(title='Transaction Side')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
monthly_sales = df.groupby('Month')['Id'].count()

### Plotting Sales Volume by Month
plt.figure(figsize=(10, 6))
bars = plt.bar(monthly_sales.index, monthly_sales.values, color='blue', alpha=0.7)
plt.title('Sales Volume by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Sales', fontsize=12)
plt.xticks(ticks=range(1, 13), labels=range(1, 13), rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, int(yval), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
### Average Price by Side
avg_price_side = df.groupby('Side')['Price'].mean()

plt.figure(figsize=(8, 5))
bars = plt.bar(avg_price_side.index, avg_price_side.values, color=['blue', 'green'])
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'${yval:,.2f}', ha='center', va='bottom')
plt.title('Average Price by Side')
plt.xlabel('Side')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %%
price_bins = [0, 250000, 500000, 1000000, 1250000]
price_labels = ['Low', 'Medium', 'High', 'Very High']

# %%
df['Price_Category'] = pd.cut(df['Price'], bins=price_bins, labels=price_labels, right=False)

# %%
avg_price_category = df.groupby('Price_Category')['Price'].mean()

#### Plot the average price by price category
plt.figure(figsize=(8, 5))
avg_price_category.plot(kind='bar', color='cyan')
plt.title('Average Price by Price Category')
plt.xlabel('Price Category')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
for index, value in enumerate(avg_price_category):
    plt.text(index, value, f'${value:,.0f}', ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_29600\886145879.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_price_category = df.groupby('Price_Category')['Price'].mean()

# %%
#df.to_csv("PastSalesAnalysis.csv", index = False, encoding = "UTF-8")
